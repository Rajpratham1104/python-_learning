# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install request
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request

# %%
pip install django
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
# ...

# %%
pip install Django==5.2.5
# Out:
# ...
#
# ...

# %%
import random

# %%
random.randint(10,40)
# Out:
# 13

# %%
import pandas as pd

# %%
pd.json_normalize({"name":["shubham", "abhi"], "age":[20,21]})"
# Out:
#   Cell In[21], line 1
#     pd.json_normalize({"name":["shubham", "abhi"], "age":[20,21]})"
#                                                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
choices(["shubham", "sahil", "rex", "tarun"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 choices(["shubham", "sahil", "rex", "tarun"])
#
# NameError: name 'choices' is not defined

# %%
from datetime import datetime

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 8, 19, 13, 28, 48, 421635)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 8, 19, 13, 29, 25, 207591)

# %%
d=datetime.now()

# %%
d
# Out:
# datetime.datetime(2025, 8, 19, 13, 31, 23, 669110)

# %%
datetime.strftime(d, "%d %B %Y")
# Out:
# '19 August 2025'

# %%
from random import choice

# %%
choice(["a","b","c"])
# Out:
# 'c'

# %%
li=[2,4, 6, 8]
a=[]
for i in li :
    
    s=i**2
    a.append(s)
print(li)
print(a)
# Out:
# [2, 4, 6, 8]
# [4, 16, 36, 64]

# %%
#list comprehension 
a=[]
for i in  range (5):
            a.append(random.randint(10, 30))
a
# Out:
# [17, 14, 29, 15, 11]

# %%
a=[random.randint(10,30) 
  for i in range(5)]
a
# Out:
# [25, 25, 10, 10, 30]

# %%
l=[i**2 for i in a]
print(a)
print(l)
# Out:
# [25, 25, 10, 10, 30]
# [625, 625, 100, 100, 900]

# %%
name = ['shubham', 'sahil', 'jatin']
age = [20,25,30]

# %%
d = {}
for i, j in zip(name,age):
    d[i] = j

# %%
d
# Out:
# {'shubham': 20, 'sahil': 25, 'jatin': 30}
